# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
import collections, random
wordCounts = collections.Counter(int_words)
totWords = len(int_words)

# %%
## Your code here
def subsample(training_set, threshold):
    retarr = []
    for word in training_set:
        occurence = wordCounts[word]/totWords
        if(1-np.sqrt(threshold/occurence) < random.random()):
            retarr.append(word)
    return retarr

# %%
#need to look at best way to figure out below threshold
train_words = subsample(int_words, 1e-5)# The final subsampled word list
print(len(train_words))
# Out:
# 4627690

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    start = random.randint(idx-window_size, idx) if idx-window_size>=0 else 0
    end = (random.randint(idx, idx+window_size+1)) if (idx+window_size) < len(words) else len(words)
    #print(words[start:end]) 
    
    return words[start:end]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,[None], name='inputs')
    labels = tf.placeholder(tf.int32,[None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                       labels, embed,
                                       n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.5871 0.3016 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.4634 0.3022 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.3360 0.3054 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.3485 0.3039 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.2262 0.3061 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.2282 0.2991 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.2064 0.2979 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.1571 0.2972 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.0717 0.2977 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.0703 0.2969 sec/batch
# Nearest to six: complexes, elaborately, vulnerabilities, weak, dull, ideal, pressed, amongst,
# Nearest to united: utilitarian, carpenter, credentes, outburst, surveyor, soapbox, lonesome, mataram,
# Nearest to from: schwa, clockrate, hristo, orchid, assay, adulthood, embroidered, genocide,
# Nearest to many: functionary, karts, archery, asceticism, geoffrey, operators, listen, ashoka,
# Nearest to three: pseudoarchaeology, warping, pricking, callixtus, posed, crawford, constans, herndon,
# Nearest to while: henceforth, las, darkening, oersted, swirling, capacitors, romanek, defensa,
# Nearest to as: reputations, seretse, reiches, zx, prospect, lonsdale, enterprising, hypersonic,
# Nearest to than: verona, ten, gunning, ulster, humvee, friar, scholar, joaquim,
# Nearest to cost: special, prodigies, sensibility, camouflage, ricci, omission, machiavellian, vandalism,
# Nearest to units: indigenous, mittag, thane, neum, congresses, fatality, dhtml, pieter,
# Nearest to gold: zooplankton, reschedule, moloch, diphthong, picardy, chloramphenicol, onlookers, epidemics,
# Nearest to consists: pointless, scalp, vivre, swordsmanship, trending, siqueiros, fughetta, casement,
# Nearest to derived: mitre, htp, dust, next, hervey, gustave, forerunner, banquo,
# Nearest to governor: undated, walnut, unwise, exegetes, homage, cardinality, resignations, bowery,
# Nearest to heavy: mermaids, lockport, pogo, signing, norfolk, aunt, belfort, beijing,
# Nearest to mainly: bounded, pseudopods, collecting, nuremberg, psych, minims, gdu, vainly,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.1027 0.3008 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.0068 0.2996 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.9891 0.3045 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.9000 0.3108 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.8708 0.3053 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.8130 0.3078 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.7585 0.3136 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.7674 0.3098 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.7178 0.3102 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.6977 0.3149 sec/batch
# Nearest to six: amongst, inventor, weak, ideal, complexes, pressed, second, centuries,
# Nearest to united: outburst, utilitarian, credentes, laws, drawn, carpenter, development, namely,
# Nearest to from: five, situations, schwa, met, clockrate, adherents, example, orchid,
# Nearest to many: functionary, operators, two, archery, range, closed, renowned, geoffrey,
# Nearest to three: pseudoarchaeology, warping, alcoholism, discussion, pricking, routes, posed, crawford,
# Nearest to while: henceforth, strong, took, las, gold, sri, capacitors, else,
# Nearest to as: reputations, spoken, prospect, zx, reiches, evolution, required, controversial,
# Nearest to than: ten, ulster, verona, limited, divided, gunning, proved, amount,
# Nearest to cost: special, omission, prodigies, sensibility, zee, ricci, guns, constance,
# Nearest to units: indigenous, mittag, thane, dhtml, pieter, neum, congresses, fatality,
# Nearest to gold: diphthong, zooplankton, reschedule, content, epidemics, while, the, moloch,
# Nearest to consists: merging, scalp, osiris, shanty, genuine, trending, pointless, ideal,
# Nearest to derived: mitre, next, dust, htp, hervey, forerunner, togo, backlash,
# Nearest to governor: unwise, undated, walnut, homage, resignations, jennifer, cardinality, exegetes,
# Nearest to heavy: mermaids, norfolk, lockport, pogo, signing, aunt, heated, beijing,
# Nearest to mainly: bounded, pseudopods, collecting, nuremberg, talib, psych, developing, vainly,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.6582 0.3238 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.6109 0.3217 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.5418 0.3059 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.5669 0.3040 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.5077 0.3218 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.5078 0.3102 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.4853 0.3304 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.4727 0.3346 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.4757 0.3103 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.4722 0.2981 sec/batch
# Nearest to six: inventor, amongst, westward, centuries, turn, kent, complexes, ideal,
# Nearest to united: carpenter, utilitarian, credentes, outburst, laws, peers, drawn, surveyor,
# Nearest to from: schwa, met, situations, clockrate, orchid, adherents, five, genocide,
# Nearest to many: functionary, operators, range, closed, listen, alfred, association, renowned,
# Nearest to three: crawford, posed, pricking, alcoholism, pseudoarchaeology, affectionately, warping, discussion,
# Nearest to while: henceforth, strong, oersted, las, idol, huygens, beliefs, royalties,
# Nearest to as: spoken, reputations, prospect, reiches, evolution, zx, initiation, antithesis,
# Nearest to than: ten, gunning, ulster, divided, verona, amount, spending, proved,
# Nearest to cost: special, prodigies, omission, sensibility, ricci, zee, guns, constance,
# Nearest to units: indigenous, mittag, statistical, interchangeable, dhtml, thane, fatality, crowd,
# Nearest to gold: diphthong, instrumental, reschedule, zooplankton, epidemics, moloch, mariana, exposition,
# Nearest to consists: genuine, merging, parliaments, scalp, osiris, ideal, appeals, trending,
# Nearest to derived: dust, mitre, next, htp, hervey, forerunner, gustave, backlash,
# Nearest to governor: homage, walnut, resignations, undated, unwise, discovered, thailand, rangers,
# Nearest to heavy: mermaids, signing, aunt, lockport, pogo, norfolk, zealand, beijing,
# Nearest to mainly: bounded, collecting, nuremberg, pseudopods, spite, guardian, profits, talib,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.4516 0.3038 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.4342 0.2982 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.4096 0.2987 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.3674 0.3014 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.4179 0.3166 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.4043 0.3185 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.3806 0.3158 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.4069 0.3163 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.3777 0.3149 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.3401 0.3058 sec/batch
# Nearest to six: inventor, ukraine, commitments, westward, jeff, nine, glenn, seven,
# Nearest to united: carpenter, credentes, states, utilitarian, outburst, peers, ration, triangular,
# Nearest to from: schwa, orchid, ambrose, clockrate, met, adulthood, situations, hristo,
# Nearest to many: functionary, operators, range, ovaries, pentecostals, alfred, messianic, listen,
# Nearest to three: crawford, seven, throwback, two, alcoholism, affectionately, warping, posed,
# Nearest to while: henceforth, oersted, strong, huygens, intense, royalties, idol, darkening,
# Nearest to as: reputations, spoken, initiation, chaitin, prospect, safavid, antithesis, zx,
# Nearest to than: ten, gunning, ulster, amd, verona, limited, humvee, spending,
# Nearest to cost: special, prodigies, sensibility, ricci, omission, zee, vandalism, constance,
# Nearest to units: indigenous, congresses, mittag, fatality, interchangeable, thane, dhtml, statistical,
# Nearest to gold: diphthong, instrumental, epidemics, reschedule, zooplankton, moloch, mariana, chloramphenicol,
# Nearest to consists: genuine, pointless, scalp, trending, parliaments, osiris, siqueiros, talmud,
# Nearest to derived: dust, mitre, htp, forerunner, hervey, next, gustave, conjugations,
# Nearest to governor: walnut, homage, resignations, undated, thailand, unwise, rangers, cleveland,
# Nearest to heavy: mermaids, signing, pogo, aunt, heated, lockport, beijing, norfolk,
# Nearest to mainly: bounded, collecting, pseudopods, nuremberg, fermat, vainly, spite, guardian,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.3402 0.2986 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.3416 0.2988 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.3170 0.2967 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.3259 0.2961 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.3252 0.2955 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.3300 0.2955 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.2890 0.2169 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.2716 0.2965 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.2235 0.2975 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.2180 0.3073 sec/batch
# Nearest to six: inventor, jeff, ukraine, athlete, maurice, seven, westward, eight,
# Nearest to united: states, carpenter, credentes, utilitarian, outburst, islands, peers, norway,
# Nearest to from: schwa, clockrate, orchid, met, hristo, adulthood, embroidered, ambrose,
# Nearest to many: operators, functionary, range, pentecostals, ovaries, khaled, messianic, ashoka,
# Nearest to three: crawford, seven, two, throwback, herndon, affectionately, warping, callixtus,
# Nearest to while: oersted, henceforth, strong, intense, nea, swirling, huygens, royalties,
# Nearest to as: reputations, spoken, crucially, chaitin, safavid, initiation, zx, math,
# Nearest to than: gunning, amd, amount, limited, maxima, ten, humvee, photon,
# Nearest to cost: special, prodigies, sensibility, ricci, omission, vandalism, zee, lindemann,
# Nearest to units: indigenous, interchangeable, congresses, mittag, fatality, statistical, thane, dhtml,
# Nearest to gold: moloch, instrumental, reschedule, epidemics, diphthong, chloramphenicol, exposition, mariana,
# Nearest to consists: trending, genuine, osiris, parliaments, asia, jitter, unfamiliar, latvia,
# Nearest to derived: dust, mitre, htp, conjugations, forerunner, hervey, togo, next,
# Nearest to governor: walnut, thailand, resignations, homage, undated, rangers, unwise, doubtless,
# Nearest to heavy: mermaids, pogo, signing, aunt, heated, commuters, beijing, lockport,
# Nearest to mainly: bounded, pseudopods, collecting, fermat, nuremberg, vainly, spite, bioethics,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.2096 0.3010 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.1868 0.2977 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.1487 0.2981 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.2280 0.2987 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.1891 0.2975 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.1805 0.3056 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.1588 0.2968 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.0966 0.3022 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.1316 0.2963 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.1123 0.3029 sec/batch
# Nearest to six: inventor, westward, ukraine, jeff, maurice, commitments, headset, four,
# Nearest to united: states, carpenter, credentes, islands, utilitarian, outburst, norway, kievan,
# Nearest to from: schwa, orchid, clockrate, hydroelectric, assay, hristo, situations, adulthood,
# Nearest to many: operators, pentecostals, functionary, ovaries, range, khaled, ashoka, listen,
# Nearest to three: seven, two, crawford, throwback, herndon, posed, zero, affectionately,
# Nearest to while: oersted, strong, intense, cyberbrain, removing, henceforth, beliefs, royalties,
# Nearest to as: chaitin, reputations, spoken, crucially, earners, initiation, aesthetic, safavid,
# Nearest to than: amount, gunning, divided, maxima, amd, limited, humvee, muscle,
# Nearest to cost: special, prodigies, sensibility, ricci, vandalism, omission, camouflage, zee,
# Nearest to units: indigenous, congresses, interchangeable, fatality, density, neum, dhtml, thane,
# Nearest to gold: moloch, epidemics, reschedule, chloramphenicol, exposition, diphthong, mariana, zooplankton,
# Nearest to consists: trending, jitter, siqueiros, osiris, latvia, scalp, unfamiliar, asia,
# Nearest to derived: dust, htp, mitre, conjugations, forerunner, carbide, hervey, explanations,
# Nearest to governor: thailand, walnut, resignations, homage, undated, rangers, liturgies, premier,
# Nearest to heavy: mermaids, pogo, signing, aunt, heated, commuters, lockport, beijing,
# Nearest to mainly: bounded, pseudopods, collecting, fermat, nuremberg, spite, vainly, evict,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.1198 0.3064 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.1021 0.2967 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.1233 0.3111 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.0887 0.3096 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.1022 0.3041 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.1355 0.2995 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.0849 0.2970 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.0689 0.2984 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.0915 0.2978 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.0575 0.3075 sec/batch
# Nearest to six: westward, inventor, four, headset, eight, maurice, ukraine, legislators,
# Nearest to united: states, carpenter, credentes, norway, zambia, ecb, eapc, islands,
# Nearest to from: schwa, orchid, clockrate, hristo, embroidered, headers, adulthood, tabriz,
# Nearest to many: pentecostals, operators, functionary, ovaries, ashoka, scents, listen, messianic,
# Nearest to three: seven, two, crawford, zero, throwback, herndon, posed, warping,
# Nearest to while: oersted, henceforth, strong, cyberbrain, idol, intense, removing, centrioles,
# Nearest to as: reputations, chaitin, crucially, spoken, antithesis, earners, aesthetic, zx,
# Nearest to than: maxima, divided, amount, humvee, wears, amd, gunning, limited,
# Nearest to cost: special, prodigies, sensibility, vandalism, ricci, tracking, machiavellian, disk,
# Nearest to units: density, interchangeable, congresses, indigenous, statistical, thane, dhtml, fatality,
# Nearest to gold: moloch, epidemics, exposition, chloramphenicol, reschedule, mariana, zooplankton, diphthong,
# Nearest to consists: trending, jitter, osiris, unfamiliar, genuine, siqueiros, merging, facets,
# Nearest to derived: htp, dust, conjugations, mitre, forerunner, depeche, carbide, explanations,
# Nearest to governor: walnut, thailand, resignations, homage, undated, premier, fijian, equatorial,
# Nearest to heavy: mermaids, heated, pogo, commuters, signing, lockport, haast, masturbate,
# Nearest to mainly: bounded, collecting, pseudopods, nuremberg, spite, fermat, vainly, evict,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.0461 0.2987 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.0796 0.2991 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.0442 0.3017 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.0444 0.2982 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.0563 0.3049 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.0442 0.3121 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.0717 0.3042 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.0565 0.3111 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.0067 0.3167 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.0125 0.3189 sec/batch
# Nearest to six: westward, four, headset, eight, ukraine, three, legislators, inventor,
# Nearest to united: states, carpenter, credentes, norway, eapc, zambia, nations, utilitarian,
# Nearest to from: clockrate, orchid, schwa, hydroelectric, embroidered, hristo, tabriz, headers,
# Nearest to many: pentecostals, ashoka, ovaries, functionary, scents, messianic, operators, listen,
# Nearest to three: seven, two, zero, posed, est, throwback, four, warping,
# Nearest to while: oersted, cyberbrain, removing, idol, nea, henceforth, swirling, strong,
# Nearest to as: reputations, chaitin, crucially, aesthetic, spoken, hypersonic, antithesis, zx,
# Nearest to than: maxima, wears, humvee, exoplanet, rayon, foci, divided, limited,
# Nearest to cost: special, vandalism, sensibility, prodigies, ricci, tracking, machiavellian, availability,
# Nearest to units: density, congresses, interchangeable, indigenous, thane, designation, dhtml, neum,
# Nearest to gold: moloch, reschedule, epidemics, exposition, mariana, picardy, chloramphenicol, itu,
# Nearest to consists: trending, jitter, osiris, merging, parliaments, siqueiros, castellano, facets,
# Nearest to derived: htp, conjugations, dust, forerunner, mitre, carbide, depeche, associated,
# Nearest to governor: thailand, resignations, homage, walnut, undated, premier, judiciary, rangers,
# Nearest to heavy: mermaids, heated, pogo, commuters, explosions, masturbate, haast, halogen,
# Nearest to mainly: bounded, pseudopods, collecting, spite, vainly, evict, denard, fermat,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.0475 0.3096 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 3.9607 0.2987 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.0663 0.2977 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.0597 0.3098 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.0876 0.3138 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 3.9699 0.3182 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 3.9683 0.3155 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.0108 0.3161 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 3.9072 0.2977 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 3.9487 0.2981 sec/batch
# Nearest to six: eight, four, inventor, westward, headset, seven, legislators, nine,
# Nearest to united: states, carpenter, credentes, eapc, zambia, norway, utilitarian, nations,
# Nearest to from: embroidered, tabriz, orchid, hristo, assay, clockrate, schwa, hydroelectric,
# Nearest to many: pentecostals, ovaries, ashoka, scents, listen, operators, functionary, conjectured,
# Nearest to three: seven, two, zero, est, posed, four, warping, throwback,
# Nearest to while: oersted, henceforth, idol, nea, swirling, cyberbrain, intense, removing,
# Nearest to as: chaitin, reputations, crucially, antithesis, zx, hypersonic, safavid, wrapper,
# Nearest to than: wears, maxima, exoplanet, humvee, foci, rayon, pours, enantiomers,
# Nearest to cost: special, vandalism, prodigies, availability, ricci, sensibility, ims, tracking,
# Nearest to units: density, designation, interchangeable, congresses, statistical, thane, evading, indigenous,
# Nearest to gold: moloch, reschedule, epidemics, traded, picardy, mariana, apostolicae, zealander,
# Nearest to consists: jitter, trending, parliaments, merging, divided, castellano, benefiting, scalp,
# Nearest to derived: htp, conjugations, dust, mitre, forerunner, associated, depeche, carbide,
# Nearest to governor: thailand, resignations, walnut, undated, judiciary, premier, homage, lieutenant,
# Nearest to heavy: mermaids, heated, pogo, commuters, masturbate, bechtel, haast, cavity,
# Nearest to mainly: bounded, pseudopods, collecting, spite, evict, denard, vainly, bioethics,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 3.9951 0.3071 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 3.9947 0.2995 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.0271 0.1366 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 3.9333 0.2989 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 3.9119 0.3052 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 3.9193 0.3003 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 3.9024 0.2980 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 3.9184 0.2994 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 3.9026 0.3091 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 3.8692 0.3115 sec/batch
# Nearest to six: headset, four, westward, eight, legislators, mccheese, inventor, second,
# Nearest to united: states, carpenter, credentes, zambia, eapc, utilitarian, norway, mataram,
# Nearest to from: tabriz, embroidered, assay, hydroelectric, clockrate, adulthood, schwa, graphein,
# Nearest to many: pentecostals, ovaries, ashoka, listen, conjectured, messianic, karts, functionary,
# Nearest to three: seven, two, zero, est, posed, four, warping, herndon,
# Nearest to while: oersted, swirling, texcoco, henceforth, nea, cyberbrain, removing, defensa,
# Nearest to as: reputations, chaitin, antithesis, aesthetic, crucially, wrapper, zx, spoken,
# Nearest to than: humvee, maxima, wears, foci, exoplanet, rayon, divided, enantiomers,
# Nearest to cost: special, vandalism, availability, ims, sensibility, tracking, machiavellian, prodigies,
# Nearest to units: density, designation, infantry, interchangeable, thane, congresses, neum, dhtml,
# Nearest to gold: moloch, silver, reschedule, content, epidemics, picardy, traded, attracts,
# Nearest to consists: jitter, trending, parliaments, divided, merging, benefiting, administratively, castellano,
# Nearest to derived: conjugations, htp, mitre, dust, forerunner, depeche, associated, carbide,
# Nearest to governor: thailand, resignations, undated, walnut, premier, judiciary, simcoe, appoints,
# Nearest to heavy: mermaids, heated, pogo, commuters, haast, cavity, masturbate, explosions,
# Nearest to mainly: bounded, collecting, pseudopods, spite, evict, fermat, vainly, bioethics,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 3.9408 0.3172 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 3.9065 0.3187 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 3.8889 0.3124 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 3.8047 0.3064 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 3.8357 0.3006 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 3.8351 0.2995 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 3.8206 0.3009 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 3.8740 0.3002 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 3.8769 0.2991 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 3.8460 0.3002 sec/batch
# Nearest to six: headset, four, eight, westward, legislators, mccheese, initials, second,
# Nearest to united: states, carpenter, eapc, credentes, zambia, utilitarian, mataram, homogeneity,
# Nearest to from: embroidered, headers, assay, clockrate, tabriz, graphein, orchid, schwa,
# Nearest to many: pentecostals, listen, ovaries, ashoka, inherits, conjectured, forgetting, scents,
# Nearest to three: seven, two, zero, est, four, posed, herndon, warping,
# Nearest to while: oersted, cyberbrain, defensa, texcoco, nea, removing, intense, swirling,
# Nearest to as: chaitin, aesthetic, antithesis, reputations, wrapper, such, crucially, zx,
# Nearest to than: wears, humvee, maxima, enantiomers, foci, divided, exoplanet, microstructure,
# Nearest to cost: special, vandalism, availability, ims, machiavellian, disk, sensibility, prodigies,
# Nearest to units: density, designation, infantry, thane, neum, interchangeable, congresses, transversal,
# Nearest to gold: silver, moloch, content, epidemics, attracts, reschedule, zealander, pyrite,
# Nearest to consists: jitter, consisting, trending, merging, mmol, divided, benefiting, parliaments,
# Nearest to derived: conjugations, htp, mitre, forerunner, dust, depeche, associated, carbide,
# Nearest to governor: thailand, resignations, undated, walnut, premier, judiciary, appoints, simcoe,
# Nearest to heavy: mermaids, heated, pogo, commuters, air, failed, hulls, haast,
# Nearest to mainly: bounded, collecting, pseudopods, spite, claris, evict, vainly, theropods,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 3.8642 0.2996 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 3.9140 0.2991 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 3.8720 0.2974 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 3.8283 0.2994 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 3.8532 0.2971 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 3.8456 0.3144 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 3.8739 0.3106 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 3.7992 0.3175 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 3.7994 0.3109 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 3.8669 0.3111 sec/batch
# Nearest to six: four, headset, eight, mccheese, westward, two, deaths, restarting,
# Nearest to united: states, eapc, carpenter, credentes, kingdom, zambia, mataram, nations,
# Nearest to from: embroidered, headers, tabriz, assay, clockrate, kliper, zoologischer, orchid,
# Nearest to many: pentecostals, listen, ashoka, ovaries, functionary, conjectured, recife, messianic,
# Nearest to three: seven, two, zero, posed, est, four, runways, warping,
# Nearest to while: oersted, texcoco, nea, defensa, removing, cyberbrain, idol, nukem,
# Nearest to as: chaitin, antithesis, aesthetic, crucially, zx, allophones, reputations, such,
# Nearest to than: wears, humvee, maxima, rather, microstructure, enantiomers, less, divided,
# Nearest to cost: special, vandalism, ims, disk, availability, prodigies, machiavellian, sensibility,
# Nearest to units: density, designation, infantry, thane, colby, transversal, neum, brigadier,
# Nearest to gold: silver, moloch, content, pyrite, attracts, reschedule, mining, copper,
# Nearest to consists: jitter, divided, consisting, parliaments, trending, administratively, merging, transferable,
# Nearest to derived: conjugations, htp, mitre, forerunner, depeche, dust, formants, translates,
# Nearest to governor: resignations, thailand, judiciary, undated, walnut, appoints, premier, equatorial,
# Nearest to heavy: mermaids, heated, pogo, commuters, lockport, haast, failed, pounders,
# Nearest to mainly: bounded, collecting, pseudopods, spite, evict, claris, bioethics, vainly,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 3.8506 0.3134 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 3.8650 0.3155 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 3.8269 0.3095 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 3.8511 0.3136 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 3.8583 0.3125 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 3.7859 0.3162 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 3.8422 0.3278 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 3.7882 0.3483 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 3.8594 0.3460 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 3.8982 0.3392 sec/batch
# Nearest to six: four, eight, headset, three, deaths, five, mccheese, nine,
# Nearest to united: states, eapc, credentes, carpenter, kingdom, mataram, bitterly, utilitarian,
# Nearest to from: tabriz, embroidered, headers, kliper, broly, indiscriminately, ambrose, zoologischer,
# Nearest to many: pentecostals, ashoka, functionary, listen, ovaries, recife, conjectured, countless,
# Nearest to three: seven, two, zero, four, posed, est, runways, herndon,
# Nearest to while: oersted, texcoco, defensa, henceforth, idol, nea, cyberbrain, removing,
# Nearest to as: chaitin, antithesis, aesthetic, reputations, such, allophones, lazar, zx,
# Nearest to than: wears, humvee, rather, maxima, divided, less, enantiomers, microstructure,
# Nearest to cost: special, vandalism, disk, ims, machiavellian, prodigies, availability, lindemann,
# Nearest to units: density, designation, infantry, thane, congresses, brigadier, neum, colby,
# Nearest to gold: silver, moloch, content, nuevo, copper, pyrite, traded, attracts,
# Nearest to consists: jitter, consisting, divided, trending, administratively, transferable, merging, parliaments,
# Nearest to derived: conjugations, htp, mitre, forerunner, formants, translates, depeche, stems,
# Nearest to governor: resignations, thailand, undated, walnut, judiciary, lieutenant, simcoe, appoints,
# Nearest to heavy: mermaids, heated, pogo, commuters, lockport, hulls, pounders, haast,
# Nearest to mainly: bounded, collecting, pseudopods, spite, claris, evict, vainly, theropods,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 3.9104 0.3280 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 3.8180 0.3238 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 3.8027 0.3208 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 3.7967 0.3213 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.7221 0.3212 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 3.8316 0.3315 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 3.8019 0.3036 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 3.7813 0.3025 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 3.8301 0.0577 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 3.7692 0.2993 sec/batch
# Nearest to six: four, headset, eight, restarting, second, mccheese, initials, legislators,
# Nearest to united: states, carpenter, eapc, credentes, kingdom, mataram, nations, utilitarian,
# Nearest to from: embroidered, assay, tabriz, headers, indiscriminately, kliper, zoologischer, broly,
# Nearest to many: pentecostals, renowned, ovaries, countless, ashoka, conjectured, listen, recife,
# Nearest to three: seven, two, posed, zero, est, four, runways, herndon,
# Nearest to while: oersted, texcoco, nea, defensa, expressive, swirling, idol, cyberbrain,
# Nearest to as: such, chaitin, aesthetic, crucially, zx, antithesis, allophones, reputations,
# Nearest to than: less, wears, rather, humvee, maxima, divided, microstructure, enantiomers,
# Nearest to cost: special, vandalism, ims, disk, machiavellian, prodigies, availability, cdma,
# Nearest to units: designation, density, infantry, congresses, brigadier, airborne, interchangeable, artillery,
# Nearest to gold: silver, content, moloch, nuevo, pyrite, traded, copper, cane,
# Nearest to consists: divided, consisting, jitter, administratively, trending, elected, transferable, merging,
# Nearest to derived: conjugations, htp, mitre, forerunner, translates, depeche, formants, dust,
# Nearest to governor: resignations, undated, thailand, walnut, judiciary, appoints, lieutenant, simcoe,
# Nearest to heavy: mermaids, pogo, heated, commuters, lockport, camp, failed, hulls,
# Nearest to mainly: pseudopods, collecting, bounded, spite, claris, evict, bioethics, theropods,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 3.7552 0.3044 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 3.7505 0.3012 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 3.7529 0.2983 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.7559 0.3004 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 3.7698 0.2998 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.7191 0.2990 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 3.7578 0.3031 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 3.7581 0.3001 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 3.7934 0.2996 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.6905 0.3002 sec/batch
# Nearest to six: four, headset, eight, second, restarting, mccheese, three, legislators,
# Nearest to united: states, eapc, kingdom, carpenter, credentes, nations, mataram, vyborg,
# Nearest to from: tabriz, embroidered, kliper, assay, headers, indiscriminately, orchid, zoologischer,
# Nearest to many: pentecostals, ovaries, ashoka, countless, conjectured, renowned, listen, materialize,
# Nearest to three: seven, two, posed, four, zero, est, lvares, warping,
# Nearest to while: oersted, texcoco, nea, defensa, shinji, cyberbrain, crescentic, expressive,
# Nearest to as: such, chaitin, antithesis, allophones, crucially, aesthetic, zx, mosque,
# Nearest to than: less, wears, rather, humvee, divided, maxima, microstructure, enantiomers,
# Nearest to cost: special, vandalism, ims, machiavellian, disk, cdma, prodigies, efficiently,
# Nearest to units: designation, density, infantry, brigadier, congresses, airborne, colby, transversal,
# Nearest to gold: silver, content, moloch, nuevo, copper, pyrite, attracts, traded,
# Nearest to consists: consisting, divided, jitter, administratively, trending, elected, appointed, transferable,
# Nearest to derived: conjugations, mitre, htp, forerunner, stems, translates, depeche, dust,
# Nearest to governor: resignations, undated, thailand, judiciary, walnut, premier, lieutenant, appoints,
# Nearest to heavy: mermaids, pogo, heated, lockport, camp, failed, hulls, commuters,
# Nearest to mainly: collecting, pseudopods, bounded, spite, claris, bioethics, developing, evict,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.6740 0.3035 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.7108 0.2984 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.6709 0.2989 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.7178 0.2980 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 3.7191 0.2982 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.7180 0.2993 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 3.7217 0.3001 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 3.7580 0.2999 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.7406 0.2996 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.7102 0.3003 sec/batch
# Nearest to six: four, headset, eight, three, second, restarting, two, leftarm,
# Nearest to united: states, kingdom, eapc, carpenter, credentes, nations, mataram, utilitarian,
# Nearest to from: embroidered, tabriz, headers, assay, indiscriminately, kliper, broly, zoologischer,
# Nearest to many: pentecostals, ovaries, countless, ashoka, conjectured, scents, listen, renowned,
# Nearest to three: seven, two, four, est, posed, zero, runways, lvares,
# Nearest to while: oersted, texcoco, nea, shinji, crescentic, defensa, nukem, expressive,
# Nearest to as: such, chaitin, allophones, antithesis, analogously, aesthetic, wrapper, crucially,
# Nearest to than: rather, less, wears, humvee, maxima, divided, microstructure, enantiomers,
# Nearest to cost: special, vandalism, ims, disk, cdma, machiavellian, costs, prodigies,
# Nearest to units: designation, density, infantry, brigadier, colby, congresses, airborne, transversal,
# Nearest to gold: silver, content, copper, pyrite, alkaline, moloch, traded, nuevo,
# Nearest to consists: consisting, divided, jitter, trending, appointed, administratively, horizontally, elected,
# Nearest to derived: conjugations, htp, mitre, forerunner, depeche, dust, stems, formants,
# Nearest to governor: resignations, undated, thailand, judiciary, walnut, chambers, lieutenant, premier,
# Nearest to heavy: mermaids, pogo, heated, hulls, pounders, lockport, camp, commuters,
# Nearest to mainly: collecting, pseudopods, spite, bounded, claris, evict, subtly, chloroplast,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.7103 0.3034 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 3.7389 0.3004 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 3.7277 0.3010 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.6754 0.2985 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 3.7371 0.3001 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.7094 0.3007 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 3.7471 0.2992 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 3.7189 0.3000 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 3.7384 0.2989 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 3.7309 0.3001 sec/batch
# Nearest to six: four, eight, headset, second, legislators, restarting, three, pepsico,
# Nearest to united: states, kingdom, eapc, carpenter, mataram, credentes, nations, devin,
# Nearest to from: tabriz, embroidered, zoologischer, broly, headers, kliper, orchid, assay,
# Nearest to many: pentecostals, ashoka, countless, ovaries, renowned, infallible, conjectured, listen,
# Nearest to three: seven, two, posed, est, four, lvares, zero, runways,
# Nearest to while: oersted, texcoco, nea, crescentic, shinji, defensa, expressive, cyberbrain,
# Nearest to as: such, chaitin, allophones, antithesis, analogously, crucially, perceived, rats,
# Nearest to than: rather, wears, less, humvee, divided, maxima, mulatto, microstructure,
# Nearest to cost: special, vandalism, machiavellian, ims, cdma, disk, prodigies, costs,
# Nearest to units: designation, density, infantry, brigadier, colby, congresses, airborne, thane,
# Nearest to gold: silver, pyrite, content, alkaline, copper, nuevo, moloch, traded,
# Nearest to consists: consisting, divided, jitter, administratively, appointed, elected, trending, ropes,
# Nearest to derived: conjugations, htp, forerunner, mitre, formants, translates, depeche, stems,
# Nearest to governor: resignations, undated, lieutenant, judiciary, thailand, appoints, general, walnut,
# Nearest to heavy: mermaids, pogo, heated, camp, hulls, lockport, failed, pounders,
# Nearest to mainly: spite, collecting, pseudopods, claris, bounded, evict, subtly, chloroplast,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 3.7303 0.3033 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.6827 0.2996 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.6723 0.3000 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 3.7356 0.3013 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 3.7212 0.3019 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 3.7945 0.3006 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 3.7913 0.3008 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.7002 0.2994 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.6950 0.2973 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 3.6800 0.2982 sec/batch
# Nearest to six: four, eight, headset, second, heft, legislators, household, restarting,
# Nearest to united: states, kingdom, carpenter, eapc, nations, credentes, mataram, hyperlinked,
# Nearest to from: headers, embroidered, zoologischer, kliper, assay, tabriz, broly, indiscriminately,
# Nearest to many: pentecostals, ashoka, ovaries, renowned, countless, conjectured, scents, reservation,
# Nearest to three: seven, two, posed, est, runways, chunnel, lvares, four,
# Nearest to while: oersted, texcoco, nea, shinji, defensa, crescentic, kampf, henceforth,
# Nearest to as: such, chaitin, allophones, rats, crucially, antithesis, analogously, chasen,
# Nearest to than: rather, less, wears, humvee, divided, maxima, mulatto, microstructure,
# Nearest to cost: vandalism, special, machiavellian, ims, cdma, disk, costs, prodigies,
# Nearest to units: designation, infantry, density, brigadier, airborne, colby, congresses, lieutenant,
# Nearest to gold: silver, alkaline, content, pyrite, nuevo, copper, traded, moloch,
# Nearest to consists: consisting, divided, jitter, administratively, trending, appointed, ropes, elected,
# Nearest to derived: conjugations, mitre, forerunner, htp, translates, depeche, stems, formants,
# Nearest to governor: resignations, undated, lieutenant, general, walnut, judiciary, thailand, appoints,
# Nearest to heavy: mermaids, pogo, heated, hulls, failed, camp, lockport, pounders,
# Nearest to mainly: pseudopods, collecting, spite, claris, bounded, subtly, chloroplast, theropods,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.6358 0.3022 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.6861 0.2980 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.7023 0.2996 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.6838 0.2982 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 3.7368 0.2988 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.6972 0.2747 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.6970 0.2988 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.6513 0.3014 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.6585 0.2991 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.6400 0.2979 sec/batch
# Nearest to six: four, eight, headset, second, christina, restarting, heft, three,
# Nearest to united: states, kingdom, carpenter, credentes, mataram, eapc, hyperlinked, enter,
# Nearest to from: assay, embroidered, tabriz, headers, zoologischer, indiscriminately, broly, kliper,
# Nearest to many: pentecostals, ovaries, ashoka, countless, renowned, conjectured, scents, eradicate,
# Nearest to three: seven, two, four, posed, federico, chunnel, feb, herndon,
# Nearest to while: nea, texcoco, shinji, crescentic, oersted, defensa, hatfield, cyberbrain,
# Nearest to as: such, allophones, chaitin, rats, antithesis, analogously, perceived, crucially,
# Nearest to than: less, rather, wears, maxima, humvee, microstructure, divided, mulatto,
# Nearest to cost: special, vandalism, disk, costs, ims, cdma, machiavellian, overhaul,
# Nearest to units: designation, infantry, density, brigadier, airborne, congresses, colby, transversal,
# Nearest to gold: silver, content, copper, traded, pyrite, alkaline, nuevo, moloch,
# Nearest to consists: consisting, divided, jitter, administratively, trending, elected, appointed, hydrographic,
# Nearest to derived: conjugations, mitre, forerunner, depeche, translates, htp, skulls, stems,
# Nearest to governor: resignations, undated, general, lieutenant, thailand, walnut, simcoe, judiciary,
# Nearest to heavy: mermaids, pogo, failed, hulls, heated, camp, pounders, lockport,
# Nearest to mainly: collecting, pseudopods, spite, claris, chloroplast, subtly, bioethics, fermat,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.6404 0.3031 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.6010 0.2994 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.6768 0.2971 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.6609 0.2990 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.6829 0.2990 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.6497 0.2980 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.5763 0.2971 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.6279 0.2997 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.5944 0.2983 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.6186 0.2986 sec/batch
# Nearest to six: four, headset, eight, second, household, christina, legislators, restarting,
# Nearest to united: states, kingdom, carpenter, credentes, mataram, hyperlinked, eapc, nations,
# Nearest to from: assay, headers, embroidered, zoologischer, tabriz, broly, indiscriminately, kliper,
# Nearest to many: pentecostals, ovaries, ashoka, renowned, countless, torontonians, scents, conjectured,
# Nearest to three: seven, two, four, posed, runways, total, est, chunnel,
# Nearest to while: oersted, nea, texcoco, crescentic, defensa, shinji, cyberbrain, expressive,
# Nearest to as: such, allophones, chaitin, analogously, rats, chasen, oe, antithesis,
# Nearest to than: less, rather, wears, humvee, divided, maxima, syme, slower,
# Nearest to cost: vandalism, special, cdma, costs, ims, machiavellian, disk, prodigies,
# Nearest to units: designation, infantry, density, brigadier, congresses, airborne, colby, transversal,
# Nearest to gold: silver, content, copper, pyrite, alkaline, traded, moloch, nuevo,
# Nearest to consists: consisting, divided, jitter, trending, ropes, appointed, administratively, horizontally,
# Nearest to derived: conjugations, forerunner, mitre, depeche, translates, htp, skulls, stems,
# Nearest to governor: resignations, undated, general, lieutenant, thailand, walnut, premier, judiciary,
# Nearest to heavy: mermaids, pogo, failed, hulls, crimean, lockport, smoke, pounders,
# Nearest to mainly: pseudopods, collecting, spite, claris, chloroplast, subtly, theropods, developing,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.6373 0.3023 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.6496 0.2983 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.6241 0.2990 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.6712 0.2980 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.7140 0.3007 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.6089 0.2994 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.6672 0.2995 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.6382 0.2984 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.6397 0.2985 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.6223 0.2997 sec/batch
# Nearest to six: four, eight, headset, christina, second, nine, leftarm, two,
# Nearest to united: states, kingdom, carpenter, mataram, credentes, eapc, hyperlinked, nations,
# Nearest to from: embroidered, assay, headers, zoologischer, tabriz, broly, counselor, indiscriminately,
# Nearest to many: pentecostals, ashoka, countless, ovaries, renowned, torontonians, scents, omputer,
# Nearest to three: seven, two, four, posed, feb, zero, chunnel, federico,
# Nearest to while: texcoco, oersted, crescentic, nea, shinji, defensa, cyberbrain, hatfield,
# Nearest to as: such, chaitin, allophones, chasen, antithesis, rats, analogously, perceived,
# Nearest to than: less, rather, wears, maxima, humvee, divided, more, microstructure,
# Nearest to cost: vandalism, cdma, special, disk, costs, ims, machiavellian, payment,
# Nearest to units: designation, density, infantry, brigadier, colby, congresses, airborne, transversal,
# Nearest to gold: silver, content, copper, pyrite, alkaline, traded, commendation, nuevo,
# Nearest to consists: consisting, divided, jitter, board, elected, holds, ropes, administratively,
# Nearest to derived: conjugations, forerunner, htp, translates, depeche, skulls, mitre, derive,
# Nearest to governor: resignations, general, undated, lieutenant, walnut, thailand, simcoe, judiciary,
# Nearest to heavy: mermaids, pogo, failed, hulls, heated, pounders, smoke, crimean,
# Nearest to mainly: spite, collecting, pseudopods, claris, chloroplast, developing, subtly, evict,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.6576 0.3024 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.6380 0.3007 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.6706 0.2993 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.6340 0.2986 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.6889 0.3038 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.6829 0.2996 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.6392 0.2998 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.6109 0.2984 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.6288 0.3007 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.6838 0.3004 sec/batch
# Nearest to six: four, eight, headset, christina, second, deaths, two, nine,
# Nearest to united: states, kingdom, carpenter, mataram, credentes, eapc, hyperlinked, nations,
# Nearest to from: embroidered, headers, assay, tabriz, zoologischer, indiscriminately, counselor, broly,
# Nearest to many: pentecostals, ashoka, ovaries, countless, conjectured, renowned, battling, scents,
# Nearest to three: seven, two, four, posed, zero, est, total, posthumus,
# Nearest to while: texcoco, oersted, crescentic, nea, hatfield, expressive, defensa, shinji,
# Nearest to as: such, allophones, rats, chaitin, antithesis, perceived, chasen, analogously,
# Nearest to than: rather, less, mulatto, wears, more, divided, maxima, slower,
# Nearest to cost: costs, disk, cdma, vandalism, machiavellian, ims, overhaul, special,
# Nearest to units: infantry, designation, density, brigadier, colby, congresses, airborne, artillery,
# ...
# Nearest to units: si, infantry, unit, brigadier, density, designation, sportscaster, commando,
# Nearest to gold: silver, medal, value, commendation, distinguishing, medals, traded, pyrite,
# Nearest to consists: consisting, legislators, divided, board, appointed, jitter, scalp, horizontally,
# Nearest to derived: skulls, derive, agate, depeche, conjugations, formerly, haran, from,
# Nearest to governor: resignations, general, simcoe, bermudez, appoint, lagrand, lieutenant, undated,
# Nearest to heavy: pogo, plainfield, heavily, metal, bands, solos, withstand, armored,
# Nearest to mainly: fermat, chloroplast, spite, claris, subtly, mockery, pseudopods, collecting,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.4550 0.3022 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.5047 0.3014 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.5064 0.2980 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.5213 0.2990 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.4717 0.3013 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.5022 0.2985 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.5270 0.2999 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.4727 0.2973 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.5199 0.2997 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.4913 0.2996 sec/batch
# Nearest to six: christina, four, inflicting, nine, hennecke, heft, two, second,
# Nearest to united: states, kingdom, elsevier, prep, terminator, navassa, carpenter, hadza,
# Nearest to from: assay, slidell, broly, embroidered, counselor, paraphrases, headers, thicknesses,
# Nearest to many: pentecostals, bennie, torontonians, battling, saddled, sided, countless, ashoka,
# Nearest to three: posthumus, two, four, total, seven, runways, giraffa, versus,
# Nearest to while: texcoco, hatfield, crescentic, bijapur, gol, replicator, nea, unincorporated,
# Nearest to as: such, perceived, allophones, antithesis, zhivago, rats, cords, analogously,
# Nearest to than: rather, less, more, lighter, syme, slower, chekhov, fibonacci,
# Nearest to cost: costs, funnies, cdma, premiere, racked, camouflage, casablanca, hinder,
# Nearest to units: si, infantry, unit, brigadier, density, designation, sportscaster, elon,
# Nearest to gold: silver, value, medal, distinguishing, commendation, pyrite, precious, traded,
# Nearest to consists: consisting, legislators, board, divided, appointed, scalp, judicial, horizontally,
# Nearest to derived: skulls, derive, agate, formerly, depeche, conjugations, haran, script,
# Nearest to governor: resignations, general, appoint, bermudez, simcoe, lieutenant, lagrand, prime,
# Nearest to heavy: pogo, plainfield, diamagnets, borate, heavily, smoke, aunt, expedients,
# Nearest to mainly: fermat, chloroplast, spite, claris, subtly, gracie, pseudopods, based,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.5027 0.3033 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.4901 0.3003 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.4850 0.2996 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.4582 0.2993 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.5475 0.2995 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.5335 0.3007 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.6047 0.3005 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.5142 0.2996 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.5535 0.2988 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.4644 0.2982 sec/batch
# Nearest to six: christina, four, nine, hennecke, forty, heft, two, eight,
# Nearest to united: states, kingdom, elsevier, terminator, prep, hadza, biography, carpenter,
# Nearest to from: slidell, assay, counselor, embroidered, broly, paraphrases, thicknesses, headers,
# Nearest to many: pentecostals, bennie, saddled, battling, torontonians, countless, ashoka, sided,
# Nearest to three: posthumus, two, four, total, runways, seven, giraffa, chunnel,
# Nearest to while: texcoco, hatfield, crescentic, bijapur, gol, meccans, bahini, nea,
# Nearest to as: such, allophones, perceived, antithesis, cords, zhivago, stratum, limbaugh,
# Nearest to than: rather, less, more, slower, syme, lighter, chekhov, fibonacci,
# Nearest to cost: costs, funnies, cdma, premiere, racked, disk, ims, launcher,
# Nearest to units: si, infantry, unit, brigadier, commando, disbanded, elon, density,
# Nearest to gold: silver, medal, value, traded, precious, pyrite, commendation, distinguishing,
# Nearest to consists: consisting, legislators, board, divided, scalp, judicial, horizontally, ropes,
# Nearest to derived: derive, skulls, agate, depeche, mitre, formerly, conjugations, script,
# Nearest to governor: resignations, general, bermudez, simcoe, undated, appoint, lieutenant, lagrand,
# Nearest to heavy: pogo, heavily, bands, plainfield, metal, borate, expedients, diamagnets,
# Nearest to mainly: fermat, spite, chloroplast, claris, subtly, pseudopods, based, gracie,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.4263 0.3037 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.4891 0.2992 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.4396 0.3007 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.5147 0.3003 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.4951 0.2983 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.4943 0.3000 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.5259 0.1707 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.4649 0.2977 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.4580 0.2993 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.5103 0.2990 sec/batch
# Nearest to six: christina, four, nine, inflicting, eight, campion, hennecke, second,
# Nearest to united: states, kingdom, elsevier, biography, terminator, prep, carpenter, abolitionists,
# Nearest to from: slidell, assay, broly, counselor, paraphrases, embroidered, placing, piazza,
# Nearest to many: pentecostals, bennie, battling, torontonians, saddled, countless, sided, ashoka,
# Nearest to three: posthumus, two, four, seven, runways, feb, total, rxd,
# Nearest to while: texcoco, hatfield, crescentic, bijapur, replicator, gol, eks, meccans,
# Nearest to as: perceived, such, neoptolemus, allophones, antithesis, zhivago, cords, recognizably,
# Nearest to than: rather, less, more, slower, lighter, syme, chekhov, fibonacci,
# Nearest to cost: costs, funnies, cdma, racked, overhaul, disk, ims, hinder,
# Nearest to units: si, infantry, unit, racial, brigadier, elon, designation, commando,
# Nearest to gold: silver, medal, value, distinguishing, commendation, traded, medals, pyrite,
# Nearest to consists: consisting, legislators, divided, board, ropes, appointed, elbridge, judicial,
# Nearest to derived: derive, skulls, depeche, agate, mitre, formerly, uma, hydrochloric,
# Nearest to governor: resignations, bermudez, general, undated, simcoe, lieutenant, appoint, lagrand,
# Nearest to heavy: pogo, metal, heavily, plainfield, bands, borate, stoner, aunt,
# Nearest to mainly: fermat, chloroplast, based, spite, claris, pseudopods, mockery, ingvar,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.4615 0.3010 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.4821 0.2997 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.4423 0.2993 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.4586 0.3000 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.4846 0.2998 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.4674 0.2984 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.5118 0.2967 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.3983 0.2995 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.4399 0.2990 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.4234 0.2997 sec/batch
# Nearest to six: four, christina, two, nine, inflicting, eight, hennecke, heft,
# Nearest to united: states, kingdom, elsevier, hadza, prep, terminator, navassa, biography,
# Nearest to from: assay, slidell, derived, paraphrases, broly, thicknesses, placing, counselor,
# Nearest to many: pentecostals, torontonians, saddled, bennie, battling, countless, paraphernalia, sided,
# Nearest to three: two, four, posthumus, total, seven, runways, giraffa, feb,
# Nearest to while: texcoco, hatfield, crescentic, bijapur, gol, replicator, shrank, eks,
# Nearest to as: such, allophones, perceived, cords, neoptolemus, rats, antithesis, chewed,
# Nearest to than: rather, less, more, slower, lighter, fibonacci, cheaper, syme,
# Nearest to cost: costs, funnies, racked, premiere, casablanca, cdma, launcher, overhaul,
# Nearest to units: si, unit, infantry, racial, elon, brigadier, density, designation,
# Nearest to gold: silver, medal, value, medals, precious, distinguishing, commendation, traded,
# Nearest to consists: consisting, legislators, board, divided, appointed, judicial, scalp, elbridge,
# Nearest to derived: derive, skulls, agate, root, depeche, from, formerly, mitre,
# Nearest to governor: resignations, bermudez, general, appoint, simcoe, undated, lieutenant, lagrand,
# Nearest to heavy: pogo, heavily, plainfield, metal, bands, borate, expedients, ffg,
# Nearest to mainly: fermat, chloroplast, based, spite, claris, pseudopods, cadmium, jute,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.3890 0.3015 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.4787 0.2993 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.4794 0.2988 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.4409 0.3004 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.4520 0.2985 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.5223 0.2983 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.4967 0.2996 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.4598 0.2987 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.4583 0.3002 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.4956 0.2996 sec/batch
# Nearest to six: four, christina, nine, hennecke, inflicting, eight, two, heft,
# Nearest to united: states, kingdom, elsevier, prep, hadza, navassa, karate, carpenter,
# Nearest to from: slidell, assay, placing, broly, paraphrases, counselor, lovin, thicknesses,
# Nearest to many: pentecostals, bennie, countless, torontonians, saddled, battling, sided, krill,
# Nearest to three: two, four, posthumus, seven, total, versus, feb, giraffa,
# Nearest to while: texcoco, hatfield, crescentic, bijapur, replicator, shrank, gol, dinneen,
# Nearest to as: such, allophones, perceived, cords, neoptolemus, antithesis, democratically, exothermic,
# Nearest to than: rather, less, more, slower, lighter, chekhov, fibonacci, cheaper,
# Nearest to cost: costs, funnies, premiere, racked, casablanca, launcher, cdma, camouflage,
# Nearest to units: si, infantry, unit, density, elon, racial, brigadier, transversal,
# Nearest to gold: silver, medal, value, commendation, medals, distinguishing, precious, copper,
# Nearest to consists: consisting, legislators, board, divided, steps, ropes, appointed, judicial,
# Nearest to derived: derive, skulls, agate, root, depeche, formerly, uma, haran,
# Nearest to governor: resignations, general, bermudez, simcoe, appoint, undated, lieutenant, lagrand,
# Nearest to heavy: pogo, plainfield, bands, heavily, metal, borate, clothe, ffg,
# Nearest to mainly: fermat, chloroplast, spite, based, claris, pseudopods, gracie, evict,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.5002 0.3030 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.4439 0.2995 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.4538 0.3003 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.4723 0.2999 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.4873 0.2989 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.4903 0.2988 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.4658 0.2979 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.4854 0.2980 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.4442 0.3001 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.4514 0.2997 sec/batch
# Nearest to six: four, christina, nine, eight, two, inflicting, hennecke, three,
# Nearest to united: states, kingdom, navassa, elsevier, nations, prep, hadza, commonality,
# Nearest to from: slidell, assay, paraphrases, counselor, placing, broly, kombinate, derived,
# Nearest to many: pentecostals, torontonians, saddled, bennie, countless, sided, battling, krill,
# Nearest to three: posthumus, two, four, seven, total, versus, runways, chunnel,
# Nearest to while: texcoco, hatfield, crescentic, bijapur, replicator, shrank, gol, eks,
# Nearest to as: such, perceived, cords, allophones, neoptolemus, democratically, chewed, antithesis,
# Nearest to than: rather, less, more, slower, lighter, cheaper, chekhov, fibonacci,
# Nearest to cost: costs, funnies, premiere, casablanca, racked, camouflage, ims, launcher,
# Nearest to units: si, infantry, unit, racial, brigadier, elon, designation, density,
# Nearest to gold: silver, medal, value, commendation, copper, precious, distinguishing, medals,
# Nearest to consists: consisting, legislators, board, divided, subordinate, judicial, appointed, ropes,
# Nearest to derived: derive, root, skulls, script, haran, agate, depeche, from,
# Nearest to governor: resignations, appoint, lieutenant, general, bermudez, simcoe, lagrand, undated,
# Nearest to heavy: metal, pogo, bands, plainfield, heavily, cherenkov, borate, expedients,
# Nearest to mainly: fermat, chloroplast, based, spite, claris, subtly, gracie, evict,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.5119 0.3032 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.4778 0.2986 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.5789 0.2995 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.5392 0.2994 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.5272 0.3012 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.4762 0.3005 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.3961 0.2992 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.4794 0.2966 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.3692 0.2992 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.5071 0.2992 sec/batch
# Nearest to six: four, nine, christina, eight, heft, two, hennecke, gtc,
# Nearest to united: states, kingdom, elsevier, navassa, biography, prep, hadza, terminator,
# Nearest to from: slidell, assay, paraphrases, lovin, counselor, kombinate, broly, placing,
# Nearest to many: pentecostals, countless, saddled, torontonians, bennie, battling, elites, krill,
# Nearest to three: posthumus, two, four, total, seven, chunnel, giraffa, runways,
# Nearest to while: texcoco, hatfield, crescentic, bijapur, replicator, gol, eks, precaution,
# Nearest to as: such, perceived, allophones, cords, neoptolemus, democratically, antithesis, chewed,
# Nearest to than: rather, less, more, slower, cheaper, lighter, chekhov, fibonacci,
# Nearest to cost: costs, funnies, ims, racked, premiere, camouflage, disk, launcher,
# Nearest to units: si, unit, infantry, elon, racial, kilograms, designation, acura,
# Nearest to gold: silver, medal, value, commendation, medals, precious, copper, traded,
# Nearest to consists: consisting, legislators, board, divided, subordinate, ropes, turboprops, judicial,
# Nearest to derived: derive, root, depeche, agate, skulls, haran, pdas, translates,
# Nearest to governor: resignations, bermudez, appoint, general, undated, simcoe, lagrand, lieutenant,
# Nearest to heavy: pogo, metal, plainfield, bands, cherenkov, heavily, stoner, expedients,
# Nearest to mainly: fermat, chloroplast, based, spite, claris, pseudopods, evict, mockery,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.4905 0.3015 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.4815 0.2997 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-a4718e25bc97> in <module>()
#       1 viz_words = 500
#       2 tsne = TSNE()
# ----> 3 embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])
#
# /Users/krotovd/anaconda/envs/tensorflow/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in fit_transform(self, X, y)
#     882             Embedding of the training data in low-dimensional space.
#     883         """
# --> 884         embedding = self._fit(X)
#     885         self.embedding_ = embedding
#     886         return self.embedding_
#
# /Users/krotovd/anaconda/envs/tensorflow/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in _fit(self, X, skip_num_points)
#     787                           X_embedded=X_embedded,
#     788                           neighbors=neighbors_nn,
# --> 789                           skip_num_points=skip_num_points)
#     790
#     791     def _tsne(self, P, degrees_of_freedom, n_samples, random_state,
#
# /Users/krotovd/anaconda/envs/tensorflow/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in _tsne(self, P, degrees_of_freedom, n_samples, random_state, X_embedded, neighbors, skip_num_points)
#     845         opt_args['it'] = it + 1
#     846         params, kl_divergence, it = _gradient_descent(obj_func, params,
# --> 847                                                       **opt_args)
#     848         if self.verbose:
#     849             print("[t-SNE] KL divergence after %d iterations with early "
#
# /Users/krotovd/anaconda/envs/tensorflow/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in _gradient_descent(objective, p0, it, n_iter, objective_error, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, min_error_diff, verbose, args, kwargs)
#     386     for i in range(it, n_iter):
#     387         new_error, grad = objective(p, *args, **kwargs)
# --> 388         grad_norm = linalg.norm(grad)
#     389
#     390         inc = update * grad >= 0.0
#
# /Users/krotovd/anaconda/envs/tensorflow/lib/python3.5/site-packages/scipy/linalg/misc.py in norm(a, ord, axis, keepdims)
#     127     """
#     128     # Differs from numpy only in non-finite handling and the use of blas.
# --> 129     a = np.asarray_chkfinite(a)
#     130
#     131     # Only use optimized norms if axis and keepdims are not specified.
#
# /Users/krotovd/anaconda/envs/tensorflow/lib/python3.5/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#    1213     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#    1214         raise ValueError(
# -> 1215             "array must not contain infs or NaNs")
#    1216     return a
#    1217
#
# ValueError: array must not contain infs or NaNs

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-112-f98e3593a546> in <module>()
#       1 fig, ax = plt.subplots(figsize=(14, 14))
#       2 for idx in range(viz_words):
# ----> 3     plt.scatter(*embed_tsne[idx, :], color='steelblue')
#       4     plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
#
# NameError: name 'embed_tsne' is not defined
